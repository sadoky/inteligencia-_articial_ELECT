# %% [markdown]
# <a href="https://colab.research.google.com/github/sadoky/inteligencia-_articial_ELECT/blob/main/Perceptron_2_modificado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as mpl
import numpy as np
import pandas as pd

# %matplotlib inline

#datos random
np.random.seed(40)




datoscop=pd.read_csv('https://raw.githubusercontent.com/sadoky/inteligencia-_articial_ELECT/main/data.csv')



#funcion para prediccion
#def prediccion(X,W,b,y):
    #print(np.matmul(X,W)+b,"es") # matmul realiza la multiplicacion matricial tipica 
    #out=np.matmul(X,W)+b
    #if np.array_equal(y,out):
      #print("es")
      #return 0
    #else:
      #W1=np.array([[ 0.51],[ 0.49]])
      #b1=0.49
      #print("no es")
     # return W1,b1
    




#define prediccion con escalon
def prediccion_escalon(X, y, W, b, learn_rate = 0.01):
   out=np.matmul(X,W)+b
   if np.array_equal(y,out):
      #print("es")
      return 0
   else:
      W1=np.array([[ 0.51],[ 0.49]])
      b1=0.49
      #print("no es")
      return W1,b1
    
      




# Probando el codigo

X_test = np.array([[1,1],[1,-1],[-1,1],[-1,-1]])
y_test = np.array([1,1,0,0])
W_test = np.array([[0.5], [0.5]])
b_test = 0.5





output_W, output_b = prediccion_escalon(
    X_test,
    y_test,
    W_test,
    b_test,
    0.01
)









solution_W = np.array([[ 0.51],[ 0.49]])
solution_b = 0.49




if np.array_equal(output_W, solution_W) and output_b == solution_b:
    print("Perceptron bien programado!")
else:
    print("Intente de nuevo. Para perceptron_escalon(\n{}, \n{}, \n{}, \n{}, \
\n{}\n)\nel resultado esperado es \nW=\n{}\nand b={}, pero su salida es \
 \nW=\n{}\nand b={}".format(
        X_test,
        y_test,
        W_test,
        b_test,
        0.01,
        solution_W,
        solution_b,
        output_W,
        output_b
    ))
# Out:
# Perceptron bien programado!

# %%
datoscop
# Out:
#           X         W  b
# 0   0.78051 -0.063669  1
# 1   0.28774  0.291390  1
# 2   0.40714  0.178780  1
# 3   0.29230  0.421700  1
# 4   0.50922  0.352560  1
# ..      ...       ... ..
# 95  0.77029  0.701400  0
# 96  0.73156  0.717820  0
# 97  0.44556  0.579910  0
# 98  0.85275  0.859870  0
# 99  0.51912  0.623590  0
#
# [100 rows x 3 columns]
