# %% [markdown]
# <a href="https://colab.research.google.com/github/sadoky/inteligencia-_articial_ELECT/blob/main/error_minimo_0_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gradiente_Descendiente

# %% [markdown]
# **librerias**

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# **Lectura de datos**

# %%
datoscop=pd.read_csv('https://raw.githubusercontent.com/sadoky/inteligencia-_articial_ELECT/main/data.csv')

# %% [markdown]
# **Seleccion_de_datos**

# %%
X1=datoscop["X"]      # vector de entrada X1
X2=datoscop["W"]      # vector de entrada X2

Y1=datoscop["b"]      # bandera  o vector de salida

# %% [markdown]
# **Clasificacion_de_datos**

# %%
n=100                 # nuemro de datos a clasificar 
learnrate=0.01      # tasa de aprendizaje 

seleccion_1_1=[]      # vector que clasifica los datos x1=1                   
seleccion_1_2=[]      # vector que clasifica los datos x2=1
seleccion_0_1=[]      # vector que clasifica  los datos x1=0
seleccion_0_2=[]      # vector que clasifica los datos x2=0


peso1=1
peso2=1
bias=0.3 


for i in range (n):              # ciclo necesario para  la clasificacion de los puntos Y1=1 or Y1=0
  if Y1[i]==1:
    seleccion_1_1.append(X1[i])
    seleccion_1_2.append(X2[i])
  else:
    seleccion_0_1.append(X1[i])
    seleccion_0_2.append(X2[i])

# %% [markdown]
# **Funcion_Sigmoide**

# %%
def sigmoid(x):  
    sig = 1 / (1 + math.exp(-x))     # función sigmoide
    return sig

# %% [markdown]
# **funcion_Error**

# %%
def funcion_error(x):
    return sigmoid(x) * (1 - sigmoid(x))

# %% [markdown]
# **Funcion_logaritmo_natural**

# %%
def ln(x):
    return(math.log(x))

# %%
epochs=20
peso1=1
peso2=1
bias=0.3 


for epocas in range (epochs):

 if epocas>=7:
   learnrate=0.00001



 for i in range(n):
 
  solucion=(X1[i]*peso1)+(X2[i]*peso2)+bias                              
  salida=sigmoid(solucion)


  error=Y1[i]-salida


  gradiente=funcion_error(salida)

  error_final=error*gradiente

  new1=learnrate*error_final*X1[i]
  new2=learnrate*error_final*X2[i]
  newbias=learnrate*error_final

  if Y1[i]==0:
    peso1=peso1+new1
    peso2=peso2+new2
    bias=bias+newbias


  if Y1[i]==1:
    peso1=peso1-new1
    peso2=peso2-new2
    bias=bias-newbias




print(peso1,peso2,bias)


def clasificador(peso1,peso2,bias):
  return (-bias-(peso2*x22))/peso1


x22=np.arange(0,1.2,0.1)
graph=clasificador(peso1,peso2,bias)


plt.figure(figsize=(10,6))
plt.plot(seleccion_1_1,seleccion_1_2,'o')             # valores iguales a uno
plt.plot(seleccion_0_1,seleccion_0_2,'o') 
plt.plot(x22,graph)
# Out:
# 0.5197379643310549 0.5172263886130154 -0.5555032058179954

# %%
X1_1=np.multiply(X1,3)
X2_2=np.multiply(X2,3)

# %% [markdown]
# *Error_Estimado*

# %%
def estimate(m,peso1,peso2,bias):
    step_8=0
    for i in range(m):
        solucion=(X1[i]*peso1)+(X2[i]*peso2)+bias
        step_1=1-Y1[i]
        step_2=ln(1-sigmoid(solucion))
        step_3=step_1*step_2

        step_4=Y1[i]
        step_5=ln(sigmoid(solucion))
        step_6=np.multiply(step_4,step_5)

        step_7=step_3+step_6
        step_8=step_8+step_7
    return step_8

# %%
goal_1=-0.01*estimate(100,peso1,peso2,bias)
print(goal_1)

goal_2=-0.01*estimate(100,1,1,0.3)
print(goal_2)
# Out:
# 0.7880501376866106
# 1.088711888905657

# %%
peso11=0.2
peso22=-0.5
bias22=-0.3 


for i in range (n):
 solucion3=(X1[i]*peso11)+(X2[i]*peso22)+bias22                             
 salida3=sigmoid(solucion3)
 print(salida3)
# Out:
# 0.47201340737264286
# 0.40416345220054867
# 0.42361226933706614
# 0.3887926726266844
# 0.40746956403509704
# 0.4259388823692421
# 0.3986577405624546
# 0.4089695102448953
# 0.3898825356551697
# 0.406601159734931
# 0.4093627975097618
# 0.39099373932760023
# 0.38655131262199754
# 0.3988377912968857
# 0.3925774106011028
# 0.42161333240682575
# 0.42357881909387846
# 0.4109997504541814
# 0.39107970317573587
# 0.3940797683302672
# 0.3965461833295659
# 0.37956617388891384
# 0.3946890627201591
# 0.39171261430092175
# 0.4141777952297068
# 0.3569318130412027
# 0.364356057096973
# 0.39988579138321034
# 0.4350038586856329
# 0.4168536458777073
# 0.39045763024503416
# 0.4410213480895006
# 0.3697584975375047
# 0.38035045276475865
# 0.39603156953544616
# 0.4013716857380501
# 0.401664613043224
# 0.3882201309883728
# 0.41188120243523957
# 0.41741966098250527
# 0.3965514478823197
# 0.3750760867819331
# 0.4265999382138389
# 0.37194120359625693
# 0.4231596518160236
# 0.40663542147451676
# 0.3946687555853976
# 0.37666356702220033
# 0.4131268521841201
# 0.40612352044052735
# 0.3341799096133248
# 0.3757851616128224
# 0.38692699301644257
# 0.351568226085079
# 0.4001070707206954
# 0.3812903361400103
# 0.3636927792486767
# 0.3646771160044204
# 0.3933235648052865
# 0.3680675556791448
# 0.3840549768966732
# 0.3744396889514896
# 0.3849014905737633
# 0.37057403220543483
# 0.3952843424015584
# 0.3685147142708752
# 0.37978921373189634
# 0.3816874485751531
# 0.4207461809800323
# 0.3716756380178895
# 0.34477921489238367
# 0.3855698222938034
# 0.34806423297141936
# 0.3772154788267699
# 0.3881543440684906
# 0.38344011504328634
# 0.3905780651554132
# 0.35940719772324614
# 0.39593637563071704
# 0.3681782772934988
# 0.3643326657446591
# 0.37146991884051705
# 0.3709067065062007
# 0.3784042248838034
# 0.39164756746537716
# 0.3741928383655519
# 0.3889240917157779
# 0.35464780685437797
# 0.3845471334538539
# 0.35957850948070996
# 0.34378748544355603
# 0.3834885810288103
# 0.38974124765937634
# 0.3505084525992735
# 0.37138260151208
# 0.37833013516499575
# 0.3745846914392499
# 0.3773425811297175
# 0.36368977078956727
# 0.3756692908123392

# %%
def clasificador(peso1,peso2,bias):
  return (-bias-(peso2*x22))/peso1


x22=np.arange(0,1,0.1)
graph=clasificador(peso1,peso2,bias)

# %%
plt.figure(figsize=(10,6))
plt.plot(seleccion_1_1,seleccion_1_2,'o')             # valores iguales a uno
plt.plot(seleccion_0_1,seleccion_0_2,'o') 
plt.plot(x22,graph)
